# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')

# %%
import pandas as pd
from utils.dataset import DataSet
from utils.generate_test_splits import generate_hold_out_split, read_ids

# %%
d = DataSet()
generate_hold_out_split(d)
trainID = set(read_ids("training_ids.txt", "splits"))
valID = set(read_ids("hold_out_ids.txt", "splits"))
# Out:
# Reading dataset
# Total stances: 49972
# Total bodies: 1683

# %% [markdown]
# # Hyperparams

# %%
MAX_SENT_PER_ART = 20
MAX_SENT_LEN = 30
MAX_VOCAB = 20000

# %% [markdown]
# # Set up training and validation data

# %%
train_stances = [stance for stance in d.stances if stance['Body ID'] in trainID]
train_headlines = [stance['Headline'] for stance in train_stances]
train_labels = [stance['Stance'] for stance in train_stances]
train_body = [d.articles[stance['Body ID']] for stance in train_stances]

val_stances = [stance for stance in d.stances if stance['Body ID'] in valID]
val_headlines = [stance['Headline'] for stance in val_stances]
val_labels = [stance['Stance'] for stance in val_stances]
val_body = [d.articles[stance['Body ID']] for stance in val_stances]

# %% [markdown]
# # Vectorization and Tokenization

# %%
from tensorflow.keras.layers import TextVectorization
vectorizer = TextVectorization(max_tokens=MAX_VOCAB, output_sequence_length=MAX_SENT_LEN)
vectorizer.adapt(list(d.articles.values()))

# %%
from nltk import tokenize

sent_tok_art = []
for article in train_body:
    sent_tok_art.append(tokenize.sent_tokenize(article))

# %%
sent_tok_head = []
for head in train_headlines:
    sent_tok_head.append(tokenize.sent_tokenize(head))

# %%
sent_tok_head[:]
# Out:
# [['Hundreds of Palestinians flee floods in Gaza as Israel opens dams'],
#  ["Christian Bale passes on role of Steve Jobs, actor reportedly felt he wasn't right for part"],
#  ['HBO and Apple in Talks for $15/Month Apple TV Streaming Service Launching in April'],
#  ["Spider burrowed through tourist's stomach and up into his chest"],
#  ['Accused Boston Marathon Bomber Severely Injured In Prison, May Never Walk Or Talk Again'],
#  ["Banksy 'Arrested & Real Identity Revealed' Is The Same Hoax From Last Year"],
#  ['British Aid Worker Confirmed Murdered By ISIS'],
#  ['Gateway Pundit'],
#  ["Woman detained in Lebanon is not al-Baghdadi's wife, Iraq says"],
#  ['Kidnapped Nigerian schoolgirls: Government claims ceasefire deal with Boko Haram that will bring missing girls home'],
#  ["No, that high school kid didn't make $72 million trading stocks"],
#  ['Soon Marijuana May Lead to Ticket, Not Arrest, in New York'],
#  ['Vandals add rude paint job to $2.5m Bugatti (but luckily for the owner it all turned out to be a hoax)'],
#  ['Boko Haram Denies Nigeria Cease-Fire Claim'],
#  ['No, Robert Plant Didn’t Rip Up an $800 Million Contract'],
#  ['ISIL Beheads American Photojournalist in Iraq'],
#  ["Tropical spider burrows under man's skin through scar"],
#  ['Boko Haram ceasefire ignored as violence flares in Borno state'],
#  ["NBC's Tom Brokaw reportedly wants Brian Williams fired over fabricated Iraq helicopter story"],
#  ["Would you take a bite out of the world's oldest burger?",
#   'Men keep Quarter Pounder they bought 20 YEARS ago for a friend who never showed up to meet them'],
#  ["Rumor debunked: RoboCop-style robots are not patrolling Microsoft's campus"],
#  ['Luke Somers Dies In Rescue Attempt, Sister Says; Yemeni Defense Ministry Says Unnamed US Hostage Freed'],
#  ['Christian Bale Exits Steve Jobs Movie (Exclusive)'],
#  ['Microsoft Tried Out Robot Security Guards on Its Silicon Valley Campus'],
#  ['Report: Christian Bale Just Bailed on the Steve Jobs Movie'],
#  ['Islamic Militants Post Video Claiming to Show Beheading of U.S.',
#   'Journalist'],
#  ['Insurgents killed in Nigeria despite alleged truce with Boko Haram'],
#  ['TEXAS TURKEY FARM CONTAMINATED WITH EBOLA, OVER 250,000 HOLIDAY TURKEYS INFECTED'],
#  ['SEE IT: ISIS militants caught trying to cross border into Texas, Congressman claims'],
#  ['Thanks Uncle Sam, we have your weapons airdrop: ISIS taunts America over intercepted weapons meant for Kurds'],
#  ['Report: ISIS Leader Abu Bakr Al-Baghdadi Assassinated In U.S. Airstrike'],
#  ['Fisherman lands 19 STONE catfish which could be biggest in world to be hooked'],
#  ['Would-be rapist has penis severed by angry mob'],
#  ["Taylor Lianne Chandler: Michael Phelps' Cougar Girlfriend Revealed?"],
#  ["At CBS Detroit, Fan Site 'Scuttlebutt' Is Enough to Publish Batmobile Rumor"],
#  ['Seth Rogen Is Woz'],
#  ['Experts: More facts needed on purported audio recording of Michael Brown shooting'],
#  ['Student accidentally sets college on fire during fireworks proposal'],
#  ['Planetary Alignment On Jan 4, 2015 Will Decrease Gravity For 5 Minutes Causing Partial Weightlessness'],
#  ['‘Banksy’ Instagram tribute to Charlie Hebdo victims not posted by artist'],
#  ['Boko Haram ceasefire ignored as violence flares in Borno state'],
#  ['BREAKING NEWS: ISIS beheads missing American journalist James Wright Foley as warning to US to cease action in Iraq'],
#  ['Pope Francis turns out not to have made pets in heaven comment'],
#  ['British rapper a suspect in ISIS beheading'],
#  ['A Husband Breaks Down In Tears After Lost Voicemail Message By His Late Wife Is Recovered'],
#  ['Bali Awry'],
#  ['Islamic State Leader al-Baghdadi “Not Dead”'],
#  ['Eggnog-chugging contest leads to hospital stay'],
#  ["No, it's not Tiger Woods selling an island in Lake Mälaren"],
#  ['Would-be rapist has penis severed by angry mob'],
#  ['Anna Wintour: Is Rat Infestation At NYC ‘Vogue’ Office Kim Kardashian’s Fault?'],
#  ["[UPDATED] 11 Men and 0 Women on Tonight's ESPN Domestic Violence Panel"],
#  ['Did Kim Yo-Jong Take Kim Jong Un’s Role?',
#   'North Korea Ill Health Rumors Are ‘Fabricated’'],
#  ["Islamic State leader's family detained by Lebanon, officials say"],
#  ['US confirms death of Somalia terror group leader'],
#  ['Durex Is Not Making Pumpkin Spice Condoms After All: A Hoax Debunked'],
#  ['ISLAMIC STATE BEHEADS MISSING AMERICAN JOURNALIST JAMES WRIGHT FOLEY'],
#  ["Spider Burrows Into Australian Man's Appendix Scar (VIDEO)"],
#  ["Indian civil servant sacked 'after 24-year sickie'"],
#  ["Batmobile wasn't stolen: Cops"],
#  ['Michael Brown shooting audio caught on tape?'],
#  ['BREAKING NEWS: ISIS beheads missing American journalist James Wright Foley as warning to US to cease action in Iraq'],
#  ['Biological Warfare on the Horizon?',
#   'ISIS Soldiers May Be Infected With Ebola'],
#  ["Moment Michael Brown was shot dead 'caught on audio recording': FBI handed potentially damning tape of ELEVEN shots being fired - including final volley of 'kill shots'"],
#  ['Saudi fatwa banning snowmen triggers heated debate'],
#  ['Paul Rudd Is Not the Viral Video Hero Who Tackled a Gay Basher in Dallas'],
#  ['Soldier, Gunman Killed In Shooting Incident Near Canadian Parliament'],
#  ['Everyone chill!', 'Banksy has NOT been arrested'],
#  ['New Audio Shows Michael Brown Was Shot at 11 Times'],
#  ['No, Islamic State Militants Have Not Been Caught by U.S. Border Patrol'],
#  ['Report: Audio Reveals Pause Between Gunshots When Michael Brown Was Shot'],
#  ['Canadian official identifies dead Ottawa gunman as Michael Zehaf-Bibeau'],
#  ['Apple 12-Inch MacBook Air Details Emerge; Device Could Be Thinner, Lighter Than Current Model'],
#  ["IS militant 'Jihadi John' named as Mohammed Emwazi from London"],
#  ['Islamic State militants allegedly used chlorine gas against Iraqi security forces'],
#  ['Zack Snyder Responds to Fake Stolen Batmobile Report'],
#  ['Ottawa investigates reports that Isis has captured Canadian-Israeli woman'],
#  ['Fidel Castro Dead?',
#   'Yes, He Is… But The Cuban Leader Is Alive, Death Rumors Proven False'],
#  ['Magic mushrooms found in BUCKINGHAM PALACE by Alan Titchmarsh'],
#  ['Video showing American journalist beheaded believed real, officials and family say'],
#  ['Canadian Soldier Shot At Ottawa War Memorial: Report'],
#  ['Audio recording allegedly captures moment Michael Brown was shot'],
#  ['New Audio Reveals Pause in Gunfire When Michael Brown Was Shot: Attorney'],
#  ['NYPD to issue tickets instead of arrest for weed possession, report says'],
#  ['India Rape Crisis Sees Mob Castrate Alleged Sex Attacker in Shocking Scenes'],
#  ['Michael Phelps’ alleged girlfriend says she was born intersex'],
#  ["How did a Texas plumber's truck end up with Syrian rebels?", '(+video)'],
#  ['Nigeria announces truce with Boko Haram; fate of schoolgirls unclear'],
#  ['ISLAMIC STATE BEHEADS MISSING AMERICAN JOURNALIST JAMES WRIGHT FOLEY'],
#  ["Christian Bale In Talks To Play Steve Jobs In Sony's Next Biopic"],
#  ['Nigeria Says Boko Haram Cease-Fire May Lead to Release of Kidnapped Girls'],
#  ['Calm Yourselves, Durex Has NOT Come Out With A Pumpkin Spice Condom'],
#  ['Islamic State flying three jets in Syria: monitor'],
#  ["J.J. Abrams Asks Disney To Move Up 'Star Wars: The Force Awakens' Release Date"],
#  ['Kim Jong-un relying on ‘cobra wine’ after problems with trouser snake'],
#  ['Nigeria: hopes for return of kidnapped schoolgirls rise after ceasefire reported'],
#  ['Former U.S. soldier says IS used chemical weapons in Kobani'],
#  ['North Korean dictator Kim Jong-Un to open restaurant in Scotland'],
#  ['Eyewitness Says Viral Video of Homeless Man Was Staged'],
#  ['New Audio Shows Michael Brown Was Shot at 11 Times'],
#  ['Meteorite strike in Nicaragua puzzles experts'],
#  ["Hunt for 'cruel' owner who abandoned dog at train station"],
#  ['Met police denies reports of Banksy arrest'],
#  ['Militant Group Says It Killed American Journalist in Syria'],
#  ["Rare Case: Seven Bosnian Girls, Aged 13 And 14, Fall Pregnant After Five-Day School Trip; Parents Outraged After School Cites 'Parental Neglect'"],
#  ["ISIS Claims It Kidnapped Gill Rosenberg, The First Western Woman To Fall Into The Group's Hands"],
#  ['What TBS’s Sped-Up Seinfeld Reruns Tell Us About the Sorry State of America'],
#  ['Islamic State claims to have beheaded American journalist'],
#  ['US probing claims ISIS fighters seized airdropped weapons meant for Kurds'],
#  ["Meteorite 'caused mysterious boom in Nicaragua'"],
#  ['Michael Zehaf-Bibeau, slain Ottawa shooter, had criminal record in Quebec, B.C.'],
#  ["Hope Fades for Girls' Release After Boko Haram 'Truce' Breached"],
#  ['ISIS cracks down on five confirmed Ebola cases among fighters: official'],
#  ['Nasa questions whether crater in Nicaragua caused by meteorite'],
#  ["Fears Islamic State could launch EBOLA attack on Britain after fighters 'contract virus'"],
#  ["Court Orders Probe Into Complaints Of 'Forced Castration' In Religious 'Dera' Sect"],
#  ['Saudi Arabian cleric issues fatwa against snowmen'],
#  ['Actor has his testicles stolen after meeting ‘young blonde woman at a bar’'],
#  ['Report: Possible audio tape of Michael Brown shooting'],
#  ['Amazon plans ad-supported video streaming service - NY post'],
#  ["CBI registers 'criminal conspiracy' case against Dera chief after claims 400 male followers were forcibly castrated"],
#  ['Shots Heard In Alleged Brown Shooting Recording [AUDIO]'],
#  ['Armed U.S. drones spotted flying over Syria in possible hunt for ISIS leader'],
#  ['Oh Hey, Paul Rudd Was One Of The Dallas Airport Homophobe Heroes, No Big'],
#  ['Tourist wakes to find strange red trail on his stomach - and discovers a spider has burrowed through his appendix scar and crawled UNDER his skin while on holiday in Bali'],
#  ['ISIS Video: America’s Air Dropped Weapons Now in Our Hands'],
#  ['Vice CEO Throws Down $300K on Lavish Vegas Dinner'],
#  ['What Glenn Beck Fears May Be Done With the 11 Missing Jets'],
#  ['Two GOP Congressmen Say Suspected Terrorists Caught Crossing U.S.–Mexico Border'],
#  ["'Hairgate': iPhone 6 users encounter latest Apple problem after 'bendgate'"],
#  ["Once Again, The Banksy 'Arrest' Is A Giant Hoax.", 'Repeat: A Hoax.'],
#  ["Judicial Watch's Farrell: ISIS Terrorists Did Cross Mexican Border"],
#  ['Amazon.com to open first physical store in Manhattan: DJ'],
#  ['Lynch Mob Castrates Alleged Rapist In Rajasthan'],
#  ['Return of the Mac: Seth Rogen in talks to star as Apple co-founder Steve Wozniak in upcoming Steve Jobs biopic'],
#  ['ADVISORY-Islamist rebel leader killed in U.S. strike - Somali government'],
#  ['Islamic Militants Post Video Claiming to Show Beheading of U.S.',
#   'Journalist'],
#  ['Video: Marine survives Taliban sniper headshot thanks to helmet'],
#  ['Weather Reporter Caught Writing His Name In The Snow Was NOT Ready To Go On Camera (UPDATED)'],
#  ["Cheese addiction breaks Kim Jong-un's ankles"],
#  ["PopWatch Teenager fights for the right to be recognized as Teletubbies' smiling sun-baby"],
#  ['ISIS cracks down on five confirmed Ebola cases among fighters: official'],
#  ["Media outlets identify 'Jihadi John'"],
#  ["J.J. Abrams Asks Disney To Move Up 'Star Wars: The Force Awakens' Release Date"],
#  ['iPhone Game Developer Quits Job By Hiding The Greatest Letter Of Resignation Ever Inside His Game'],
#  ['Lego letter to parents in 1974 on gender equality still resonates 40 years on'],
#  ["Christian Bale Won't Play Steve Jobs After All"],
#  ['Suspected meteorite leaves crater in Managua, is linked to asteroid'],
#  ['KIM DINE WITH ME: Porky president Kim Jong-un to open UK restaurant serving DOG'],
#  ['Canadian Soldier Shot At Ottawa War Memorial: Report'],
#  ['In Moscow, police are looking for a felon, cut the male genitals'],
#  ['Lego letter from the 1970s still offers a powerful message to parents 40 years later'],
#  ["Isis leader Abu Bakr al-Baghdadi's 'wife and son detained in Lebanon'"],
#  ["Rumor Robert Plant Ripped Up $800 Million Contract To Reunite Led Zeppelin Called 'Rubbish'"],
#  ['Michelle Obama’s face blurred by Saudi state television'],
#  ['More than 200 kidnapped Nigerian girls to be released after deal reached with Boko Haram'],
#  ['Islamic State Militants Claim to Have Beheaded US Journalist James Wright Foley'],
#  ["Islamic State killer 'Jihadi John' named as Mohammed Emwazi"],
#  ['Brian Williams Demands Apology From Social Media Over Erroneous Urination Reports (Video)'],
#  ['Pentagon: ISIS seized materials airdropped to Kurds'],
#  ['New policy could reduce marijuana possession arrests'],
#  ['Did NBC Nightly News Go Live To A Man Who Was Taking A Piss?'],
#  ["ESPN's Domestic Violence Panel Is Missing Something Important"],
#  ['Boko Haram denies it has agreed ceasefire'],
#  ['Islamic State claims to have beheaded American journalist'],
#  ["Audio recording of Michael Brown being gunned down WAS made at the time he was killed: App company appears to confirm tape of ELEVEN bullets being fired - including final volley of 'kill shots'"],
#  ['Islamic State releases video apparently showing the beheading of missing US journalist James Foley'],
#  ['Kurds Deny Gill Rosenberg was in Kobane'],
#  ['After Giving A Homeless Man $100, This Guy Secretly Filmed Him...'],
#  ['Cook said to confirm Apple Watch is showerproof, lasts a day'],
#  ["Lynch mob chop man's penis off after catching him allegedly trying to rape teenager"],
#  ['Russian Yeti Or Bigfoot Hoax?', 'New Footage Sparks Debate'],
#  ["Tropical spider burrowed under Bali tourist's skin"],
#  ['Alleged audio of Michael Brown shooting has surfaced'],
#  ['Mexico Says Missing Students Not Found In First Mass Graves'],
#  ["Boko Haram denies ceasefire claim by Nigeria's government"],
#  ['British hostage David Haines beheaded by Islamic State terrorists'],
#  ['Alleged Ottawa gunman: What we know so far about Michael Zehaf-Bibeau'],
#  ['See How This Homeless Man Spends A Hundred Dollars, And Keep A Tissue Handy [Video]'],
#  ['L. Jinny?',
#   'Abdel-Majed Abdel Bary, UK Rapper, Suspected in James Foley Killing: Reports'],
#  ["Ottawa Shooting: Soldier Shot at Canada's National War Memorial"],
#  ['Woman, Ting Su, Finds Husband Cheating With Her Own Twin, Gets Spectacular Revenge'],
#  ['North Korean leader Kim Jong-un not missing, just having ankle surgery'],
#  ['Seth Rogen reportedly nabs Steve Wozniak role in Steve Jobs filmSteve Jobs Iconic Moments'],
#  ['Police hunt tweed-jacket wearing man who slaps shoppers for SNEEZING'],
#  ['Meteorite Leaves House-Sized Crater in Nicaragua’s Capital'],
#  ["Does Vogue's New Office Have a Rat Infestation?"],
#  ['Meteorite leaves crater in Nicaraguan capital Managua'],
#  ['Homeless man receives $100... then shocks everyone with how he spends it'],
#  ['Reports: Big Bank Hank of pioneering rap group Sugarhill Gang has died'],
#  ['Kim Jong-un ‘is so fat from eating cheese that he has broken his ankles’'],
#  ["First bendgate... now it's HAIRGATE: Angry iPhone 6 owners claim design is causing chunks of their hair to be ripped out when they make a phone call"],
#  ['Vice Media Chief Said to Pay $300,000 for Dinner for 30'],
#  ["Tropical spider burrowed under man's skin through appendix scar and lived there for THREE DAYS"],
#  ['Apple Watch may be powered by Samsung processor'],
#  ['No, Saudi TV Did Not Blur Out Images of Michelle Obama'],
#  ['North Korean leader Kim Jong-un’s mystery illness actually two broken ankles, newspaper says'],
#  ['Boyfriend cuts off his penis and throws it in the bin after girlfriend dumps him for being bad in bed'],
#  ["'American bombing had signed my death certificate': Missing US journalist James Wright Foley goes unflinching to his death as ISIS behead him in horrific video, as a warning to Obama"],
#  ['More than 200 kidnapped Nigerian girls to be released after deal reached with Boko Haram'],
#  ['Despite ceasefire announcement, new Boko Haram attacks reported'],
#  ['Apple in talks to become launch partner for cable-free HBO Now service'],
#  ['Passenger Wears A Hazmat Suit To Dulles Airport'],
#  ['Woman Spends Entire Week In KFC After Getting Dumped By Her Boyfriend'],
#  ['Taliban member swapped by Obama for Bowe Bergdahl tried to return to terror: report'],
#  ['Has Ebola infected Isis militants in Mosul?'],
#  ['Watch: ISIS Claims to Have Captured U.S. Airdropped Weapons'],
#  ['#ISIS beheads photojournalist James Wright Foley in a massage to US to end its intervention in #Iraq.'],
#  ["Christian Bale won't play Steve Jobs"],
#  ['Thanks Uncle Sam, we have your weapons airdrop: ISIS taunts America over intercepted weapons meant for Kurds'],
#  ['Video Purports To Show Beheading Of U.S.', 'Journalist By Militants'],
#  ['6 Islamist militants killed in US attack in Somalia'],
#  ['This Letter To Parents From A 1970s Lego Set Contains An Important Message For Gender Equality'],
#  ['Officials Refute Iraqi Media Reports That ISIS Members Have Contracted Ebola In Mosul'],
#  ['Islamic State Training Pilots in Military Jets, Monitors Say'],
#  ['Could Kim Jong Un open a restaurant in Scotland?'],
#  ['Cheeky vandals paint giant penis on bonnet of £1.5 million Bugatti Veyron sportscar'],
#  ['Soldier shot in Ottawa at War Memorial'],
#  ['BATMAN VS. SUPERMAN BATMOBILE STOLEN'],
#  ['Did Comcast Get a Man Fired From His Job for Complaining About Its Service?'],
#  ['Video shows ISIL beheading of photojournalist James Foley'],
#  ['Isis claims it has US airdrop of weapons'],
#  ['L. Jinny?',
#   'Abdel-Majed Abdel Bary, UK Rapper, Suspected in James Foley Killing: Reports'],
#  ['Comcast blocks Tor'],
#  ['Elderly Woman Arrested for Kidnapping Neighbor’s Cats & Making Fur Coats'],
#  ['Staff Reporter'],
#  ['Lebanon detains wife and son of Al-Baghdadi'],
#  ["Reports Isis fighters have contracted Ebola are 'incorrect', says Iraqi health ministry"],
#  ['Kim Jong-un Broke Both Ankles and Is Hospitalized, Report Claims'],
#  ['New iOS 8 bug can delete all of your iCloud documents'],
#  ['TEXAS TURKEY FARM CONTAMINATED WITH EBOLA, OVER 250,000 HOLIDAY TURKEYS INFECTED'],
#  ['The Apple Watch Will Debut by Late March [Report]'],
#  ['Dylan Thomas Finds Tropical Spider Burrowed Under Skin'],
#  ['Boko Haram denies it has agreed ceasefire'],
#  ['A Wanted Man Responded To A Police Facebook Post That He Would Turn Himself In'],
#  ['Video Purports To Show Beheading Of U.S.', 'Journalist By Militants'],
#  ['Aaron Sorkin Confirms Christian Bale Will Play Steve Jobs'],
#  ['ISIS Unleash "Scorpion" Bombs In Iraq'],
#  ["Spider Burrows Into Australian Man's Appendix Scar (VIDEO)"],
#  ['Michael Phelps’ alleged girlfriend says she was born intersex'],
#  ['Despite no Ebola case in Kansas City, the rumor goes viral'],
#  ['Don’t ‘Reset All Settings’ in iOS 8 unless you want to lose your iCloud files'],
#  ['Soldier shot in Ottawa at War Memorial'],
#  ['The Pumpkin-Spice Condom Is Just a Figment of Your Own Gross Imagination'],
#  ["Canadian woman 'captured by ISIS in Syria' says she is actually fine and still fighting the jihadists, despite kidnap reports"],
#  ['More than 200 kidnapped Nigerian girls to be released after deal reached with Boko Haram'],
#  ['This Woman Is Wrongly Being Called A Sexual Predator After Her Private Sex Tape Was Used For A Hoax'],
#  ['Jihadi John UNMASKED: Islamic State killer NAMED as west Londoner Mohammed Emwazi'],
#  ['Bunbury local discovered a spider had burrowed under his skin on Bali holiday'],
#  ['No, Banksy has not been arrested (sigh)'],
#  ["DNA tests prove Lebanon IS holding ISIS chief al-Baghdadi's ex-wife and daughter after they were caught with fake passports"],
#  ['CNN Airs Alleged Audio from Michael Brown Shooting'],
#  ["Guru who ordered 400 followers to be castrated 'so they could be closer to God' is investigated for grievous bodily harm in India"],
#  ["Guantanamo detainee freed in Bowe Bergdahl swap 'back to terrorism'"],
#  ['UBS survey finds 10% of consumers want a smartwatch, expects 24M Apple Watch sales in fiscal 2015'],
#  ["Man has his PENIS cut off by angry mob after 'attempted rape' of teenager"],
#  ['Bugatti Veyron Vandalized With Penis Graffiti?',
#   'Viral Photo Isn’t What It Seems'],
#  ["Has Kim's SISTER taken over North Korea?",
#   'Dictator fails to show for key Communist event (but does send a nice flower basket instead)'],
#  ['North Korea Leader Kim Jong Un Is Still In Charge: Source'],
#  ['Former PGA Tour player: Tiger Woods suspended for drug test failure'],
#  ['NET Extra: Back-from-the-dead Catholic priest claims God is a female...'],
#  ["Isis 'fed murdered kidnap victim to his own mother after she travelled to their headquarters and demanded to see him'"],
#  ['Alleged audio of Michael Brown shooting released'],
#  ['Boyfriend cuts off his penis and throws it in the bin after girlfriend dumps him for being bad in bed'],
#  ['Man who skipped work for 24 years is finally fired'],
#  ['Big Bank Hank of The Sugarhill Gang is dead at 57'],
#  ['Isis claims to behead US journalist'],
#  ['Islamic State, in video titled "A Message to America," beheads American journalist James Wright Foley who was kidnapped in 2012'],
#  ['Viral Video Of Homeless Man Spending $100 On Food For Other Homeless Was Faked, Witness Says'],
#  ["Kim Jong-Un 'bans the name Kim Jong-un'"],
#  ['Scientists Doubt That Meteor Caused Crater In Nicaragua'],
#  ['Fence Jumper Made It Deeper Into the White House Than Secret Service Claims'],
#  ['Journalist James Wright Foley reportedly beheaded by ISIS'],
#  ['Islamic State May Have Fighter Jets Now After Seizing Russian-Made MiGs'],
#  ['Absent from duty for 25 years, CPWD official dismissed'],
#  ['Did a Meteorite Impact in Nicaragua over the Weekend?'],
#  ['Meteorite strike in Nicaragua puzzles experts'],
#  ['Fears journalist James Wright Foley beheaded by Islamic State jihadists in ‘message’ to United States'],
#  ['Zack Snyder Makes Fun of Stolen Batmobile Rumor with New Image'],
#  ['Small red book among finds in 113-year-old Boston time capsule'],
#  ['Kurds fear Isis use of chemical weapon in Kobani'],
#  ['New Audio Shows Michael Brown Was Shot at 11 Times'],
#  ['DHS Rebuffs Congressman’s Claim ISIS Infiltrating Southern Border'],
#  ["Luke Somers 'killed in failed rescue attempt in Yemen'"],
#  ['Anna Wintour: Is Rat Infestation At NYC ‘Vogue’ Office Kim Kardashian’s Fault?'],
#  ['URGENT: ISIS kills 300 Iraqi soldiers by chlorine gas attack in Saqlawiyah'],
#  ['This Letter To Parents From A 1970s Lego Set Contains An Important Message For Gender Equality'],
#  ['Ferguson riots: audio may have captured Michael Brown shooting'],
#  ['ISIS Claims an American Hostage, Kayla Mueller, Died in Airstrike in Syria'],
#  ['Did Paul Rudd Help Tackle That Dallas Airport Gay-Basher?'],
#  ['WAS NBC METEOROLOGIST MIKE SEIDEL PEEING IN THE SNOW ON CAMERA?',
#   'A TESTY BRIAN WILLIAMS EXPLAINS'],
#  ['Canadian Soldier Shot At Ottawa War Memorial: Report'],
#  ['ISIS Extremists Claim to Behead British Hostage David Haines'],
#  ['Boko Haram agrees to ceasefire, release of school girls'],
#  ['Led Zeppelin’s Robert Plant ripped up a $924 million reunion contract'],
#  ['‘Teletubbies’ Sun Baby: Fans Freak Out Over Jess Smith, 19'],
#  ['Nigeria, Boko Haram reach ceasefire deal, kidnapped girls to go free, official says'],
#  ['Boko Haram denies cease-fire, leader says he married off kidnapped girls'],
#  ['North Korea leader Kim is still in charge, has injured leg: source'],
#  ['Rumor: Gold Apple Watch Edition priced up to $5,000, steel version at $500, will debut on Feb. 14'],
#  ['ISIS Reportedly Beheads U.S.', 'Journalist James Wright Foley on Camera'],
#  ['ISIS Militants Allegedly Contracted Ebola'],
#  ['Report: Missing Libyan jetliners raise fears of suicide airliner attacks on 9/11'],
#  ['Batman Set To Play Steve Jobs In Upcoming Biopic'],
#  ['ISIS Getting Ebola'],
#  ["Obama Denounces James Foley's Execution: 'Today The Entire World Is Appalled'"],
#  ['REPORT: Alleged New Audio of Michael Brown Shooting'],
#  ["Apple Watch to Feature Time-Only 'Power Reserve' Mode, Prototypes Disguised as Samsung Watches"],
#  ['Video showing American journalist beheaded believed real, officials and family say'],
#  ['Report: Former Baseball Star Jose Canseco Accidentally Shot At Home'],
#  ["Luke Somers 'killed in failed rescue attempt in Yemen'"],
#  ['Nicaragua Meteorite Impact Theory May Be Meteor-wrong'],
#  ["No, that high school kid didn't make $72 million trading stocks"],
#  ['ISIL video claims beheading of kidnapped journalist James Foley'],
#  ['Tiger Woods serving secret PED suspension?'],
#  ['Pentagon confirms al-Shabab leader killed in airstrike in Somalia'],
#  ['Christian Bale in talks to play Steve Jobs for Sony, Danny Boyle'],
#  ['This Is Why Rumors That ISIS Is Crossing The Border Into The U.S. Aren’t Going Away'],
#  ['Nicaragua meteorite: Experts attempt to understand whether mysterious meteorite fell from passing Pitbull asteroid'],
#  ['Cook said to confirm Apple Watch is showerproof, lasts a day'],
#  ['Mum Offers to Sell Twin Boy to Save Twin Girl'],
#  ['McDonald’s Removing Big Mac, Apple Pies And Eliminating Large Size Options'],
#  ['Cold Turkey'],
#  ['Founding Fathers-Era Time Capsule Found in Boston'],
#  ['You may be able to make appointments at the Apple Store to try on the Apple Watch when it launches'],
#  ['Soldier shot at War Memorial; multiple shots fired in Parliament'],
#  ['Mass Graves Found In Mexico, Near Place Where 43 Students Went Missing'],
#  ["Whiz kid stock picker: I didn't actually make $72M trading"],
#  ['Isis video claims to show beheading of British hostage David Haines'],
#  ['ISIS leader dead?'],
#  ['British rapper a suspect in ISIS beheading'],
#  ['Jose Canseco shoots self in hand'],
#  ['New policy could reduce marijuana possession arrests'],
#  ['This Soap Opera Star Reportedly Had His Testicles Stolen By An ‘Attractive Blonde’ Organ Trafficker'],
#  ["Seth Rogen to Star as Steve Wozniak in Sony's Steve Jobs Biopic [Updated]"],
#  ['Is the Alleged Audio of the Gunshots That Killed Michael Brown a Hoax?'],
#  ['Seth Rogen to play Woz in Jobs biopic'],
#  ['ISIS cracks down on five confirmed Ebola cases among fighters: official'],
#  ["Rats at Vogue's NYC offices - watch your step, Anna Wintour"],
#  ["Mum faces real-life Sophie's Choice – as she tries to sell her son to fund daughter's care"],
#  ["Islamic State reports youngest jihadist 'martyred' in battle"],
#  ['‘Teletubbies’ Sun Baby: Fans Freak Out Over Jess Smith, 19'],
#  ['Reports: Boko Haram may release schoolgirls as part of deal'],
#  ['Report: Christian Bale Will Play Steve Jobs'],
#  ['Hilarious: North Dakota Pays Special Tribute to President Obama'],
#  ['Senior Western Intelligence Official Confirms London Rapper Abdel Majed Abdel Bary Is A Suspect In The Foley Killing'],
#  ["Apple's 12-Inch Retina MacBook Air Shown in Artist's Renditions"],
#  ['Pentagon: Somali terror group leader killed in U.S. airstrike'],
#  ["NEWS/ You'll Never Guess How a Homeless Man Spent $100—Watch the Touching Video!"],
#  ['Experts: More facts needed on purported audio recording of Michael Brown shooting'],
#  ['Microsoft turns to robotic security guards to watch for trouble'],
#  ['Amazon.com to open first physical store in Manhattan: DJ'],
#  ['Iraqi media: ISIS militants have contracted Ebola'],
#  ['Missing American journalist reportedly beheaded by Islamic State'],
#  ['UPDATE: Soldier, gunman who died in Ottawa rampage identified'],
#  ['Macaulay Culkin Dead?'],
#  ['Report: Audio Reveals Pause Between Gunshots When Michael Brown Was Shot'],
#  ["Boko Haram 'ceasefire' doubts after attacks reported in Nigeria"],
#  ["ISIS executioner 'Jihadi John' identified as Mohammed Emwazi"],
#  ['Saddam Hussein’s pilots training Islamic State group'],
#  ['WFB’s Bill Gertz: Obama Administration ‘Trying to Play Down’ Missing Libyan Airliners'],
#  ['Palestine accuses Israel of opening dams, flooding Gaza, forcing evacuations'],
#  ['Give a homeless man $100 and see what he does with it [Video]'],
#  ['Nigeria Claims Boko Haram Will Release the Kidnapped Schoolgirls'],
#  ['CNN Posts Alleged Audio of Michael Brown Shooting'],
#  ['Hospital Officials: Kansas City Patient Not Being Treated For Ebola'],
#  ['Nigeria announces truce with Boko Haram; fate of schoolgirls unclear'],
#  ['Catholic Priest Claims God Is Female After Clinically Dead Experience'],
#  ['Seth Rogen To Play Steve Wozniak In Steve Jobs Biopic'],
#  ['James Foley Killer ‘Jihadi John’ Believed to Be Former London Rapper Abdel-Majed Abdel Bary'],
#  ['Tiger Woods is not on suspension for failing a drug test, his agent and a PGA official say'],
#  ['BiH: Seven Primary School Students Pregnant After Five-Day Excursion'],
#  ['Meet the 17-Year-Old Who Made $72 Million During His High-School Lunch Breaks'],
#  ['Apple Watch launch expected in late March'],
#  ['Calm Yourselves, Durex Has NOT Come Out With A Pumpkin Spice Condom'],
#  ['Isis claims it has US airdrop of weapons'],
#  ['Nigeria: hopes for return of kidnapped schoolgirls rise after ceasefire reported'],
#  ['Report: ISIS kidnaps Canadian-Israeli, former IDF soldier who went to fight with the Kurds'],
#  ['Meteorite leaves crater in Nicaraguan capital Managua'],
#  ["Guantanamo detainee freed in Bowe Bergdahl swap 'back to terrorism'"],
#  ['Has Ebola infected Isis militants in Mosul?'],
#  ['Was The Batmobile Stolen In Detroit?'],
#  ['Apple Watch mass production kicks off in January: Report'],
#  ['US probing claims ISIS fighters seized airdropped weapons meant for Kurds'],
#  ['WFB’s Bill Gertz: Obama Administration ‘Trying to Play Down’ Missing Libyan Airliners'],
#  ['Macaulay Culkin dead: The death hoax is once again on the child actor'],
#  ['Who Is Michael Zehaf-Bibeau?',
#   'Ottawa Shooter Suspect Identified By Canadian Officials'],
#  ['GOP Rep: ‘At Least Ten ISIS Fighters Have Been Caught Coming Across The Mexican Border’'],
#  ["'Spiderman' squished: Perth experts debunk spider burrowing claims"],
#  ['God Is A Woman – Resurrected Father Narated'],
#  ['Photo gallery: Amazing £300 operation by North Walsham vet on constipated goldfish'],
#  ['Boko Haram Could Release Kidnapped Girls, Nigerian Officials Say'],
#  ["Sorry, KFC isn't going to be selling weed in Colorado restaurants"],
#  ['Matt Taibbi on leave of absence from First Look Media'],
#  ['ISIS Fighters Getting Caught Coming Across the U.S.-Mexican Border?'],
#  ['Unverified video shows beheading of aid worker David Haines'],
#  ['Dumped woman spends a week in KFC to get over ex'],
#  ['Man cuts off manhood, throws it in the bin, after girlfriend leaves over small penis'],
#  ['WTC rats scare off Anna Wintour'],
#  ['Managua explosion not a meteorite, NASA suggests'],
#  ["No, A Spider Did Not Burrow Under A Man's Skin And Live There For Days"],
#  ['Parliament Hill shooting: Sergeant-At-Arms Kevin Vickers the family hero who took down Ottawa gunman'],
#  ["In Kim Jong Un's absence, his sister may rule.", 'Or not.'],
#  ['Yemen says U.S. man freed, sister says he’s dead'],
#  ["Islamic State using 'SCORPION bombs' to terrorise victims"],
#  ['The rats eat Prada at Vogue NY office'],
#  ['What One Homeless Man Does with $100 Will Astonish You (VIDEO)'],
#  ['Parliament Hill shooting: Sergeant-At-Arms Kevin Vickers the family hero who took down Ottawa gunman'],
#  ["No, a spider (probably) didn't crawl through a man's body for several days"],
#  ['Isis tells mother on rescue mission :’You’ve just eaten your son’'],
#  ['Aaron Sorkin Confirms Christian Bale Will Play Steve Jobs'],
#  ['North Korean leader Kim Jong-un to open restaurant in Scotland'],
#  ['BREAKING UDPATED: ISIS REPORTEDLY USE CHEMICAL WEAPONS IN KOBANE'],
#  ['11 Tripoli Planes Still Missing, Sparks 9/11 Concerns'],
#  ['Pants on Fire: Duncan Hunter makes unconfirmed claim Border Patrol caught at least 10 ISIS fighters'],
#  ['North Korea ordered citizens named Kim Jong Un to change their names, says new report'],
#  ['Apple Media Event Rumored for Late February, Apple Watch and 12" MacBook Air Likely Topics [Updated]'],
#  ['Comfort eating?',
#   'Chinese woman, 26, spends an entire WEEK in KFC after being dumped by boyfriend'],
#  ['ISIS Beheads American Journalist'],
#  ['Alleged audio of Michael Brown shooting released'],
#  ['Wayward sister ‘nun the wiser’ about baby'],
#  ['North Korea denies reports Kim Jong-un is to open state-backed restaurant in Scotland'],
#  ['Islamist terrorists Jabhat Ansar al-Deen tweet picture of Texas plumber’s truck fitted with anti-aircraft gun in Syria'],
#  ['Apple-HBO Deal Seen Launching Web-only Apple TV Streaming Service For $15 Per Month'],
#  ['Breaking: Soldier shot at National War Memorial in Ottawa'],
#  ['Whoa, Paul Rudd Was One of the Airport Heroes Who Took Down the Homophobe'],
#  ['Boko Haram: Kidnapped Girls Have Been Married Off, Truce Never Happened'],
#  ["A message from Jim's mom, Diane Foley:"],
#  ['Google to buy big chunk of Pacific Shores, iconic Redwood City office park'],
#  ['NASA Raises Doubts About Reports of Nicaraguan Meteorite'],
#  ['ISIS Border Crisis: DHS Chief Says Terrorists Not Entering US Through Mexico'],
#  ['Kanye Banned'],
#  ["Rep. Duncan Hunter: 'At Least 10' ISIS Fighters Caught at Mexican Border"],
#  ["Lebanon 'holding IS leader's daughter and ex-wife'"],
#  ['Pumpkin Spice condoms?', "Don't fall for this hoax."],
#  ["Lynch mob chop man's penis off after catching him allegedly trying to rape teenager"],
#  ["“Axl Rose dead 2014” : Guns N' Roses frontman killed by internet death hoax"],
#  ['Oscar winner Christian Bale to play Steve Jobs in upcoming biopic'],
#  ['Ottawa Gunman Identified As Michael Zehaf-Bibeau'],
#  ['Ottawa shooting: Slain soldier named as Nathan Cirillo while suspect identified as Michael Zehaf-Bibeau'],
#  ['Alleged Audio of Michael Brown Shooting Doesn’t Sound Good for Officer Darren Wilson'],
#  ['British hostage David Haines beheaded by Islamic State terrorists'],
#  ['Abdel Majed Abdel Bary Emerges as Suspect in Foley Beheading'],
#  ['Nigeria Says It Struck A Cease-Fire With Boko Haram, But Are They Talking To The Right Guy?'],
#  ['Reports: Jihadists Steal Commercial Jets, Raise 9/11 Fears'],
#  ['New York City Plans to End Arrests for Possession of Small Amounts of Marijuana'],
#  ["Kim Jong-Un 'bans the name Kim Jong-un'"],
#  ['Hundreds of dog-lovers from around the world offer home to pet abandoned at the railway station with a suitcase containing his pillow, toy, bowl and favourite food'],
#  ["Once Again, The Banksy 'Arrest' Is A Giant Hoax.", 'Repeat: A Hoax.'],
#  ['Meet the X-BOY: Electric shock turns kid into MAGNETO'],
#  ['iOS 8 bug reportedly erases iCloud Drive documents when settings are reset'],
#  ['Priest who died for 48 minutes says he met God and she’s a woman'],
#  ['BREAKING: ISIS Beheads American Journalist James Wright Foley'],
#  ['Mexico Says Students Not Among Dead in Mass Grave'],
#  ['Was The Batmobile Stolen In Detroit?'],
#  ['New Audio Shows Michael Brown Was Shot at 11 Times'],
#  ['Iraqi airstrike kills key ISIL leader'],
#  ["Obama: murder of James Foley 'shocks the conscience of the entire world'"],
#  ['Seven High School Girls Get Pregnant On Five-Day School Trip, Parents Outraged'],
#  ["Apple's New MacBook Will Be A Thinner, Cleaner, Faster 12-Inch MacBook Air"],
#  ["Woman detained in Lebanon is not al-Baghdadi's wife, Iraq says"],
#  ['Audio may have captured Michael Brown shooting'],
#  ['Mechanical polar bear ‘threatened with ASBO for singing Christmas songs’'],
#  ["No, that broken pencil illustration isn't by Banksy"],
#  ['So, There Might Be a Rat Infestation at Vogue'],
#  ['Soldier shot in Ottawa at War Memorial'],
#  ['Report: Exec popped for $300k dinner after run at blackjack'],
#  ["Jeh Johnson: Politicians Shouldn't 'Feed The Flames Of Fear' Over ISIS, Ebola"],
#  ['Islamic State Militants Claim to Have Beheaded US Journalist James Wright Foley'],
#  ['Watch marine take sniper shot to the head and live'],
#  ['The baby from Teletubbies reveals herself'],
#  ["80's Brat Pack star Judd Nelson forced to deny that he's dead after fake news story starts trending on social media"],
#  ["Iraq: US to Probe ISIS' Chlorine Attack on Iraqi Security Personnel"],
#  ['Vladimir Putin’s Motorcade Looks Like A Massive Knob'],
#  ['Her Majesty’s magic mushrooms'],
#  ['Predator Drone Reportedly Sighted Circling Raqqa, Syria'],
#  ["Small Meteorite Strikes in Nicaragua's Capital City of Managua"],
#  ['Macaulay Culkin Hasn’t Died Despite What Everyone Is Saying On Facebook'],
#  ["ISIS Blasts 'Scorpion Bombs' At Civilian Areas In Iraq; Mosul Residents Living In Fear"],
#  ['Mexican cartel leader kills self; bodies in grave not missing students'],
#  ['Teen Makes $72 Million on the Stock Market'],
#  ['Singing polar bear facing ASBO after noise complaint'],
#  ['Report: Christian Bale Just Bailed on the Steve Jobs Movie'],
#  ['Priest who died for 48 minutes says he met God and she’s a woman'],
#  ['This Kid Made $72 Million During Lunch'],
#  ['Abdel-Majed Abdel Bary: London Rapper Identified As ISIS Militant Who Beheaded James Foley'],
#  ['American hostage killed in rescue attempt in Yemen - senior official'],
#  ["[UPDATED] 11 Men and 0 Women on Tonight's ESPN Domestic Violence Panel"],
#  ['What One Homeless Man Does with $100 Will Astonish You (VIDEO)'],
#  ['#ISIS beheads photojournalist James Wright Foley in a massage to US to end its intervention in #Iraq.'],
#  ['US, UK eye rapper as British-born militant who beheaded journalist James Foley'],
#  ['Nigeria Boko Haram blamed for raids despite truce claim'],
#  ['TBS Speeds up SEINFELD by 7.5% to Add 2 More Minutes of Commercials'],
#  ['New York schoolboy who made $72MILLION trading stocks on his lunch breaks - and now takes his friends out to dine on $400 caviar, drives a BMW and has definitely made his immigrant parents proud'],
#  ['Duped again: Macaulay Culkin is not dead'],
#  ['WHO says reports of suspected Ebola cases in Iraq are untrue'],
#  ['Indian worker sacked after going on leave for 24 years'],
#  ['Hidden Diagnostic Port on Apple Watch Could Allow for Smart Band Accessories [Updated]'],
#  ['Iraqi social-media rumors claim IS leader slain'],
#  ['US Intel: Taliban Man Released From Gitmo in Bergdahl Deal is Back to Militant Activity'],
#  ['ISIS Reportedly Beheads U.S.', 'Journalist James Wright Foley on Camera'],
#  ['Islamic State, in video titled "A Message to America," beheads American journalist James Wright Foley who was kidnapped in 2012'],
#  ['Experts: More facts needed on purported audio recording of Michael Brown shooting'],
#  ['See How This Homeless Man Spends A Hundred Dollars, And Keep A Tissue Handy [Video]'],
#  ['Six months after abducting Nigerian schoolgirls, Boko Haram reportedly wants to free them'],
#  ['WTC rats scare off Anna Wintour'],
#  ['Marijuana May Soon Spark Just a Ticket in New York'],
#  ['Zack Snyder Makes Fun of Stolen Batmobile Rumor with New Image'],
#  ['Macaulay Culkin Dead: Internet Death Hoax Claims Actor Found Dead In Apartment'],
#  ['Rumor: Stainless Steel Apple Watch Will Cost $500, Gold $4,000'],
#  ["Guantanamo detainee freed in Bowe Bergdahl swap 'back to terrorism'"],
#  ["Nigeria's missing girls 'to be released by Boko Haram', government aide claims"],
#  ['Armed U.S. drones spotted flying over Syria in possible hunt for ISIS leader'],
#  ['Fence jumper reportedly made it much further into White House than Secret Service said'],
#  ['Is There an ISIS Threat on the Texas-Mexico Border or Not?'],
#  ["A Predator Drone Has Reportedly Been Spotted Circling Above ISIS's Capital City"],
#  ["Sources: Guns N' Roses Frontman Axl Rose Found Dead in West Hollywood Home at Age 52"],
#  ['Explosion reported near the Nicaraguan capital attributed to meteorite impact, but experts, including NASA, cast doubt on claims'],
#  ['Mexico finds 4 more graves at site of suspected student massacre'],
#  ["Shocking picture shows mother trying to sell her own son to pay for twin daughter's cancer treatment"],
#  ['ISIS Unleash "Scorpion" Bombs In Iraq'],
#  ['Report claims Kim Jong-un underwent surgery to repair fractured ankles'],
#  ["[UPDATED] 11 Men and 0 Women on Tonight's ESPN Domestic Violence Panel"],
#  ['US Lawmaker: Ten ISIS Fighters Have Been Apprehended Coming Across Southern Border (Video)'],
#  ['Report: Christian Bale Will Play Steve Jobs'],
#  ["No, Saudi TV Didn't Blur Out Michelle Obama's Face When the President Met King Salman"],
#  ["Real-life Magneto boy 'becomes living magnet' after getting massive electric shock from street lamp"],
#  ['Big Bank Hank, US rapper and Sugarhill Gang founder member, dies at 57'],
#  ["No, that broken pencil illustration isn't by Banksy"],
#  ['North Korea denies reports Kim Jong-un is to open state-backed restaurant in Scotland'],
#  ['US drones hunt Isis leader in Syria'],
#  ['Dera Sacha Sauda Chief Forced Castration of 400 Devotees?',
#   "CBI Files Case Against 'MSG: The Messenger of God' Actor"],
#  ['Are Rumors of the Apple Watch in Feb True?'],
#  ['Boko Haram leader denies ceasefire deal, says 200 abducted girls married off'],
#  ['Resetting iOS 8 Preferences May Wipe iCloud Files'],
#  ['This Woman Exposed Her Cheating Boyfriend With A Brilliant Christmas Gift'],
#  ['Small Meteorite Hits Managua'],
#  ['Kim Jong-un Broke Both Ankles and Is Hospitalized, Report Claims'],
#  ['Google to buy big chunk of Pacific Shores, iconic Redwood City office park'],
#  ['A soldier has been shot at Canada’s war memorial just steps away from the nation’s parliament'],
#  ['Paul Rudd Helped Tackle A Violent Homophobe So That’s Another Reason To Love Him [UPDATE]'],
#  ['Who Is Michael Zehaf-Bibeau?',
#   'Ottawa Shooter Suspect Identified By Canadian Officials'],
#  ['#HairGate: iPhone 6 Customers Are Complaining That The Phone Is Ripping Out Their Hair'],
#  ['#ISIS beheads photojournalist James Wright Foley in a massage to US to end its intervention in #Iraq.'],
#  ['Norfolk Man Pays £300 For His Constipated Goldfish To Have Lifesaving Surgery'],
#  ['Comfort eating?',
#   'Chinese woman, 26, spends an entire WEEK in KFC after being dumped by boyfriend'],
#  ['US Marine survives headshot in Afghanistan'],
#  ['Man Known as ‘Jihadi John’ Is Identified as Mohammed Emwazi'],
#  ['Lawmaker Says ‘At Least 10′ Islamic State Fighters Have Been Captured at the Southern U.S. Border'],
#  ['Boko Haram Denies Truce, Says Kidnapped Girls Have Been “Married Off”'],
#  ['US hostage Luke Somers dies after rescue bid'],
#  ['James Foley, Missing American Photojournalist, Reportedly Executed By ISIS In Syria'],
#  ['US Intel: Taliban Man Released From Gitmo in Bergdahl Deal is Back to Militant Activity'],
#  ["Luke Somers: British-born photojournalist 'killed by al-Qaeda after failed rescue attempt in Yemen'"],
#  ["Christian Bale in Talks to Star in Sony's Steve Jobs Film"],
#  ["Boko Haram 'ceasefire' doubts after attacks reported in Nigeria"],
#  ['REPORT: Alleged New Audio of Michael Brown Shooting'],
#  ['Who Is Michael Zehaf-Bibeau?',
#   'Ottawa Shooter Suspect Identified By Canadian Officials'],
#  ['Russian Man Wakes Up to Find His Testicles Have Been Stolen'],
#  ['Kidnapped Nigerian schoolgirls: Government claims ceasefire deal with Boko Haram that will bring missing girls home'],
#  ['Mexico finds 4 more graves at site of suspected student massacre'],
#  ['Islamic State releases video apparently showing the beheading of missing US journalist James Foley'],
#  ['No, Saudi TV Did Not Blur Out Images of Michelle Obama'],
#  ['#HairGate: iPhone 6 Customers Are Complaining That The Phone Is Ripping Out Their Hair'],
#  ['Woman detained in Lebanon is not Isis leader’s wife, says Iraq'],
#  ["'Nasa Confirms Six Days of Darkness in December': No, they really don't - it's a hoax"],
#  ["Rare meteorite impact causes blast in Nicaragua's capital, Managua"],
#  ['The Chinese Guide to Avoiding a Bad English Name'],
#  ['Audio of gunfire in Michael Brown case authenticated by app company'],
#  ['Missing Planes'],
#  ['A Vice Guide To Spending $300,000 On Dinner'],
#  ['Unconfirmed reports of hand grenade found in a safe at Shortlands property'],
#  ['Isis video claims to show beheading of British hostage David Haines'],
#  ['Kim Jong-Un planning Scottish restaurant'],
#  ["'The Force Awakens' Release Date: JJ Abrams Plan for an Early Release of 'Star Wars' Movie?"],
#  ["Michael Phelps' self-proclaimed 'girlfriend', 41, reveals she was born a male as she describes her 'amazing intimacy' with Olympic swimmer"],
#  ['ISIS Beheading of U.S.', 'Journalist James Foley Posted to YouTube'],
#  ['BREAKING NEWS: ISIS beheads missing American journalist James Wright Foley as warning to US to cease action in Iraq'],
#  ["Texas plumber's truck on front line of Syria war"],
#  ['Canada probes Michael Zehaf-Bibeau as possible suspect in Ottawa shooting - source'],
#  ["Questions raised over Nicaragua 'meteorite'"],
#  ['RCMP release security footage of Michael Zehaf Bibeau during attack, say he shot soldier in back'],
#  ['Militant Group Says It Killed American Journalist in Syria'],
#  ["Guru who ordered 400 followers to be castrated 'so they could be closer to God' is investigated for grievous bodily harm in India"],
#  ['Islamic State claims to have beheaded American journalist'],
#  ['Pope Francis did not tell boy heaven has room for pets, contrary to report'],
#  ['White House Fence Jumper Pushed Past Female Guard'],
#  ["Sadly, Pumpkin Spice Condoms Aren't A Thing After All"],
#  ['#ISIS beheads photojournalist James Wright Foley in a massage to US to end its intervention in #Iraq.'],
#  ['Nicaraguan commission on possible meteorite crash presents rock samples'],
#  ['Video Purports To Show Beheading Of U.S.', 'Journalist By Militants'],
#  ['Weaponized Ebola?', 'ISIS Militants Said To Contract Deadly Virus'],
#  ['Government fires employee who skipped work for 24 years'],
#  ['James Wright Foley, Kidnapped Journalist, Apparently Executed by ISIS'],
#  ['Alleged audio of Michael Brown shooting released'],
#  ['Bodies In Mexico Mass Grave Apparently Not Those Of Missing Students'],
#  ['Bali spider burrows under Aussie’s chest'],
#  ['North Korean leader Kim Jong Un had ankle surgery, report says'],
#  ['Boko Haram leader denies ceasefire deal, says 200 abducted girls married off'],
#  ['Islamic State training fighter pilots in captured jets, monitoring group says'],
#  ["Once Again, The Banksy 'Arrest' Is A Giant Hoax.", 'Repeat: A Hoax.'],
#  ['Report: Israeli-Canadian woman fighting Islamic State has been kidnapped by terror group'],
#  ['Rats are still running around at Vogue'],
#  ["80's Brat Pack star Judd Nelson forced to deny that he's dead after fake news story starts trending on social media"],
#  ['Christian Bale Exits Steve Jobs Movie (Exclusive)'],
#  ['Star Wars: The Force Awakens to be released this summer?'],
#  ['The Apple Watch has a low-power mode that only tells the time'],
#  ["DNA tests prove Lebanon IS holding ISIS chief al-Baghdadi's ex-wife and daughter after they were caught with fake passports"],
#  ["Sources: Guns N' Roses Frontman Axl Rose Found Dead in West Hollywood Home at Age 52"],
#  ["The Image That Everyone Is Sharing By 'Banksy' Isn't By Banksy — But It's Awesome"],
#  ['An audio recording of the Michael Brown shooting has reportedly surfaced'],
#  ['Jordan’s King May Participate Personally In ISIS Raids'],
#  ["Magic Mushrooms Found in Queen Elizabeth's Garden at Buckingham Palace"],
#  ['U.S. airstrike kills Islamic Al Shabab terrorist leader in Somalia'],
#  ['Has The Batman Vs. Superman Batmobile Been Stolen In Detroit?'],
#  ['Libya: Missing Libya Planes Spark Security Concerns'],
#  ['Continuing Violence Puts Boko Haram Ceasefire In Jeopardy'],
#  ['Pentagon: ISIS Got U.S.', 'Weapons Package'],
#  ['Audio recording allegedly captures moment Michael Brown was shot'],
#  ['Apple Media Event Rumored for Late February, Apple Watch and 12" MacBook Air Likely Topics [Updated]'],
#  ['ISIS Beheads American Journalist'],
#  ['‘Wild Misinformation’: Brian Williams Explains the Mike Seidel Liveshot'],
#  ['The Chinese Guide to Avoiding a Bad English Name'],
#  ['Watch marine take sniper shot to the head and live'],
#  ['Nun gives birth, intends to keep baby'],
#  ['Doubts cast over Nicaragua meteorite claim'],
#  ["ISIS fighters 'have contracted Ebola': World Health Organisation investigating reports militants showed up at Iraqi hospital with lethal disease"],
#  ["Second person rushed to hospital with Ebola symptoms after contact with 'patient zero' Thomas Duncan"],
#  ["Boko Haram 'ceasefire' doubts after attacks reported in Nigeria"],
#  ['‘Star Wars: The Force Awakens’ May Get An Early Release Date—Report'],
#  ["Guru who ordered 400 followers to be castrated 'so they could be closer to God' is investigated for grievous bodily harm in India"],
#  ['Gold Apple Watch Edition price?', 'Speculators say at least $10,000'],
#  ['Tiger Woods selling Swedish villa — island included'],
# ...
#  ['Man breaks down in tears when a lost recording of his deceased wife resurfaces'],
#  ['CNN Plays Alleged Recording of Michael Brown Shooting'],
#  ['Another American hostage at risk by Islamic state'],
#  ['IPhone 6 users are tearing their hair out'],
#  ['Sick Kansas City man said not to have Ebola, U.S. plans new steps to fight virus'],
#  ["Penis Drawn On Bugatti Veyron Could Be World's Most Expensive Car Vandalism"],
#  ['What This Homeless Guy Did With $100 Completely Stunned The Man Who Gave It To Him'],
#  ['Bali Awry'],
#  ['Meteorite leaves crater in Nicaraguan capital Managua'],
#  ['Angry mob cut off rapist’s penis with meat cleaver (VIEWER DISCRETION)'],
#  ["Lynch mob use butcher's meat cleaver to castrate rapist they caught attacking teenage girl in alleyway in Indian city"],
#  ['MACAULAY CULKIN IS THE LATEST VICTIM OF A CELEBRITY DEATH HOAX — AND THESE 9 STARS KNOW EXACTLY HOW HE FEELS!'],
#  ['Islamic Militants Post Video Claiming to Show Beheading of U.S.',
#   'Journalist'],
#  ["Web of confusion as scientists cast doubt on man's claims that a spider burrowed into his stomach through his SCAR"],
#  ["Sadly, Pumpkin Spice Condoms Aren't A Thing After All"],
#  ['Sorry, Everyone: Durex Is Unfortunately Not Making Pumpkin Spice Condoms'],
#  ['Kidnapped Nigerian schoolgirls: Government claims ceasefire deal with Boko Haram that will bring missing girls home'],
#  ['Newly-Found Document Holds Eyewitness Account of Jesus Performing Miracle'],
#  ['Video showing American journalist beheaded believed real, officials and family say'],
#  ['Sorry, Fido.', 'Pope Francis did NOT say our pets are going to heaven'],
#  ['NYPD to issue tickets instead of arrest for weed possession, report says'],
#  ["The iPhone 6 'Hairgate' Is Not a Thing"],
#  ["'Spiderman' squished: Perth experts debunk spider burrowing claims"],
#  ['We took a look at the photo said to show the body of Islamic State leader Abu Bakr Al-Baghdadi (right) and found it was really an ethnic Albanian militant killed in 2013'],
#  ['6 hidden mass graves may hold missing Mexican students'],
#  ['Nigeria Says It Struck A Cease-Fire With Boko Haram, But Are They Talking To The Right Guy?'],
#  ['Audio of gunfire in Michael Brown case authenticated by app company'],
#  ['Star Wars 7: JJ Abrams want to move release to summer 2015'],
#  ["'The youngest martyr - the cub of al-Baghdadi': ISIS boasts a 10-year-old fighter has been killed as he went into battle with his father in Syria"],
#  ['ISIS Fighters Getting Caught Coming Across the U.S.-Mexican Border?'],
#  ['Bunbury local discovered a spider had burrowed under his skin on Bali holiday'],
#  ["Luke Somers: British-born photojournalist 'killed by al-Qaeda after failed rescue attempt in Yemen'"],
#  ['Saudis Say Michelle Obama Not Blurred on TV'],
#  ["Second person rushed to hospital with Ebola symptoms after contact with 'patient zero' Thomas Duncan"],
#  ['A Wanted Man Responded To A Police Facebook Post That He Would Turn Himself In'],
#  ['Woman detained in Lebanon is not Isis leader’s wife, says Iraq'],
#  ['WAS NBC METEOROLOGIST MIKE SEIDEL PEEING IN THE SNOW ON CAMERA?',
#   'A TESTY BRIAN WILLIAMS EXPLAINS'],
#  ['Macaulay Culkin dead hoax: Fake death report spreads on social networks'],
#  ['BREAKING UDPATED: ISIS REPORTEDLY USE CHEMICAL WEAPONS IN KOBANE'],
#  ['$YUM Serving Up #Marijuana & Fried Chicken'],
#  ['Boyfriend cuts off his penis and throws it in the bin after girlfriend dumps him for being bad in bed'],
#  ['Reports of missing Libyan planes raise 9/11 terror fears'],
#  ['Comcast gets customer fired for complaining about poor service'],
#  ['Is Ebola Virus Spreading Among ISIS Militants?',
#   'Reports Claim Jihadists Seeking Cure at Mosul Hospital'],
#  ['Is Kim Jong-Un Really Opening a Restaurant in Scotland?'],
#  ['Zack Snyder Makes Fun of Stolen Batmobile Rumor with New Image'],
#  ['Mass grave found after 40 students disappear in Mexican protest'],
#  ['Fake Fox News Website Reports Judd Nelson’s Death for Some Reason'],
#  ['This Woman Exposed Her Cheating Boyfriend With A Brilliant Christmas Gift'],
#  ['You all had an abortion!', '[Google Translate]'],
#  ['Parliament Hill shooting: Sergeant-At-Arms Kevin Vickers the family hero who took down Ottawa gunman'],
#  ['Watch moment TV weatherman is caught urinating in the bushes LIVE on camera'],
#  ["Christian Bale won't play Steve Jobs"],
#  ['Report: Possible audio tape of Michael Brown shooting'],
#  ["Rapper identified as James Foley's executioner: reports"],
#  ['11 Tripoli Planes Still Missing, Sparks 9/11 Concerns'],
#  ['Mechanical polar bear ‘threatened with ASBO for singing Christmas songs’'],
#  ['See the Crater a Meteorite Made in Nicaragua'],
#  ['Sugarhill Gang rapper Big Bank Hank dies aged 57'],
#  ["BREAKING: British-born hostage 'KILLED in failed rescue attempt'"],
#  ['Ebola Frisco 2014: Patient Shows Virus Symptoms After Apparent Thomas Eric Duncan Contact'],
#  ["Christian Bale in Talks to Play Steve Jobs in Danny Boyle's Biopic"],
#  ['Female Israeli fighter said abducted by Islamic State  Read more: Female Israeli fighter said abducted by Islamic State'],
#  ['Report of Kim Jong-un’s ankle injury add fuel to rumours about his absence'],
#  ["Predator drones being flown over Isil's Syrian 'capital'"],
#  ['Islamic State claims it executed American photojournalist James Foley'],
#  ['Macaulay Culkin Dead?', 'Fans Freak Out Over Death Rumors'],
#  ['Vandal paints penis on £1.5million Bugatti Veyron'],
#  ['Insiders Claim Steel Apple Watch to Start at $500, Gold at $4,000'],
#  ["Islamic State killer 'Jihadi John' named as Mohammed Emwazi"],
#  ["Don't forget to tip...especially if you spend $300,000"],
#  ['Man chops off his own penis after girlfriend told him he was no good in bed'],
#  ['ISIS militants appear to behead abducted American journalist James Wright Foley in graphic video'],
#  ['Penis graffiti drawn on £1.5million Bugatti Veyron'],
#  ['Dead for 48 minutes, this Catholic Priest claims God is female'],
#  ['Managua explosion not a meteorite, NASA suggests'],
#  ['Watch US Marine get shot in HEAD by Taliban sniper - and live to tell tale'],
#  ['New Audio Shows Michael Brown Was Shot at 11 Times'],
#  ['CNN Airs Alleged Audio from Michael Brown Shooting'],
#  ['ISIS Beheads Kidnapped Photojournalist James Wright Foley in Horrific Video Message to the U.S.'],
#  ['Is the Alleged Audio of the Gunshots That Killed Michael Brown a Hoax?'],
#  ['Man chops off own penis after being dumped by his girlfriend'],
#  ['Islamic Militants Post Video Claiming to Show Beheading of U.S.',
#   'Journalist'],
#  ["Letter From Lego To Parents In The '70s Makes An Important Point About Gender"],
#  ['Mystery man slaps shoppers around head for sneezing'],
#  ['Nun Gives Birth To Baby Boy After Suffering Intense Stomach Pains'],
#  ["Vogue's new digs are reportedly swarming with rats"],
#  ['Boko Haram denies it has agreed ceasefire'],
#  ["Kim Jong-un 'set to open a new restaurant in SCOTLAND'"],
#  ['Boko Haram claims to have German hostage, denies ceasefire'],
#  ['Soldier shot at war memorial in Canada'],
#  ['That Story About a Catholic Priest Dying, Seeing God as a Woman, and Coming Back to Life?',
#   'It’s Almost Definitely Fake'],
#  ['US confirms death of Somalia terror group leader'],
#  ["Banksy arrest hoax: Internet duped by fake report claiming that the street artist's identity has been revealed"],
#  ['Lawmaker Says ‘At Least 10′ Islamic State Fighters Have Been Captured at the Southern U.S. Border'],
#  ['Six months after abducting Nigerian schoolgirls, Boko Haram reportedly wants to free them'],
#  ['Bali spider burrows under Aussie’s chest'],
#  ['Islamic State training pilots to fly MiG fighter planes, says monitoring group'],
#  ['Amazon plans a streaming-video alternative'],
#  ['The Chinese Guide to Avoiding a Bad English Name'],
#  ["PGA Spokesman and Tiger Woods' Agent Deny Drug Suspension Allegations"],
#  ['Boko Haram leader denies ceasefire deal, says 200 abducted girls married off'],
#  ['Macaulay Culkin Dead: Internet Death Hoax Claims Actor Found Dead In Apartment'],
#  ['Terrorism fears rise amid reports of stolen jetliners'],
#  ['Apple 12-Inch MacBook Air Details Emerge; Device Could Be Thinner, Lighter Than Current Model'],
#  ['BREAKING: Islamic State, in video, beheads American journalist James Wright Foley who was kidnapped in 2012 -@BNONews'],
#  ["Kim Jong-Un 'in hospital with two fractured ankles' after ballooning to around 20 stone and going on numerous 'meet the people' walkabout PR stunts"],
#  ['A Bunch Of People Thought Banksy Got Arrested But It Was A Hoax'],
#  ['Microsoft Hires Dalek-style Robocops to Guard Silicon Valley HQ'],
#  ['Saddam Hussein’s pilots training Islamic State group'],
#  ['CNN Posts Alleged Audio of Michael Brown Shooting'],
#  ['ESPN’s All-Male “Monday Night Football” Panel On Domestic Violence Is Not Real'],
#  ["Here Are Microsoft's New Robot Security Guards"],
#  ['Boko Haram Could Release Kidnapped Girls, Nigerian Officials Say'],
#  ['Wife and child of Islamic State leader Baghdadi held in Lebanon'],
#  ['Cold Turkey'],
#  ["Homeland Security says terrorists haven't crossed U.S-Mexico border"],
#  ["Christian Bale In Talks To Play Steve Jobs In Sony's Next Biopic"],
#  ['Macklemore Gets Twitter-Trolled with the #MacklemoreJoinedISIS'],
#  ['Purported ISIS claim: Jordan airstrike kills female US hostage'],
#  ['AWESOME!',
#   'Canadian Parliament’s Sergeant-at-Arms Kevin Vickers Takes Out Gunman'],
#  ['ISIS Fighters Getting Caught Coming Across the U.S.-Mexican Border?'],
#  ['Elderly Woman Arrested for Kidnapping Neighbor’s Cats & Making Fur Coats'],
#  ["ISIS Releases YouTube Video Showing 10-Year-Old 'Martyr' Allegedly Killed in Battle"],
#  ['Boko Haram Cease-Fire: Abducted Nigerian Schoolgirls To Be Released, Officials Say'],
#  ['Boko Haram ceasefire ignored as violence flares in Borno state'],
#  ['The Internet Tried To Make Axl Rose Its Latest Death Hoax Victim'],
#  ['Predator Drone Reportedly Spotted Over ISIS Hotbed in Syria; Airstrikes Hit ISIS Targets'],
#  ['Italian fisherman catches monstrous 280-pound catfish'],
#  ['Nigeria: hopes for return of kidnapped schoolgirls rise after ceasefire reported'],
#  ['Jose Canseco injured in accidental shooting, per reports'],
#  ['U.S. accidentally delivered weapons to the Islamic State by airdrop, militants say'],
#  ['Isilkulskom student has gained superhero powers after shock'],
#  ['Confusion Surrounds Capture Of “ISIS Leader’s Wife”'],
#  ['Kidnapped Nigerian schoolgirls: Government claims ceasefire deal with Boko Haram that will bring missing girls home'],
#  ["Hunt for 'cruel' owner who abandoned dog at train station"],
#  ['Chinese State Media Warns People To Stop Calling Themselves Dumbledore'],
#  ["Kim Jong-un necks litres of rare SNAKE wine because he's too fat to please his wife"],
#  ["Video Messaging App Says Audio Recording Of Michael Brown's Shooting Is Authentic"],
#  ['Ottawa Gunman Identified As Michael Zehaf-Bibeau'],
#  ['Report: Apple Watch to start at $500 in stainless steel, thousands for gold model'],
#  ['FBI Probing Alleged Audio of Michael Brown Shooting'],
#  ['Missing Libyan aircraft spark fears of 9/11-style attack in North Africa'],
#  ["The iPhone 6 'Hairgate' Is Not a Thing"],
#  ["Nun complains of stomach pains... and GIVES BIRTH: Sister who had 'no idea' she was pregnant has a baby boy at hospital in Italy"],
#  ["World's oldest burger"],
#  ['‘Jihadi John’: The Islamic State killer behind the mask is a young Londoner'],
#  ['No, Islamic State Militants Have Not Been Caught by U.S. Border Patrol'],
#  ['Iraqi media says ISIS militants have contracted Ebola'],
#  ['HORROR: ISIS Fighters Have Reportedly Contracted Ebola'],
#  ['7 teen girls get pregnant on school trip Read more at http://www.wnd.com/2014/12/7-teen-girls-get-pregnant-on-school-trip/#F5filOd6yFpASPV9.99'],
#  ['Saudis Say Michelle Obama Not Blurred on TV'],
#  ['New Audio Shows Michael Brown Was Shot at 11 Times'],
#  ['ISIS Getting Ebola'],
#  ['Claim: Comcast Got Complaining Customer Fired From His Job'],
#  ['Etats-Unis: Mort pendant 48 minutes, un prêtre affirme que Dieu est une femme'],
#  ['Islamic Militants Post Video Claiming to Show Beheading of U.S.',
#   'Journalist'],
#  ['Gateway Pundit'],
#  ['CNN Broadcasts Purported Audio Containing Gunshots That Felled Michael Brown Jr.; Leaders, Celebrities Fill Pews At Teen’s Funeral'],
#  ['Chugging eggnog at office party lands man in hospital'],
#  ['Isis tells mother on rescue mission :’You’ve just eaten your son’'],
#  ['IS Beheads Briton David Cawthorne Haines, Threatens to Execute Another Briton, Alan Henning'],
#  ["Elderly Woman Arrested for Kidnapping Neighbor's Cats & Making Fur Coats"],
#  ['Former British Rapper Reportedly Under Investigation for James Foley Beheading'],
#  ["Urgent: The Leader of ISIL 'Abu Bakr al-Baghdadi' Killed!", '/ Photo'],
#  ["'Jihadi John' named as Mohammed Emwazi from London"],
#  ['It’s About To Get Harder To Be Arrested For Pot Possession In New York City'],
#  ['Turkish Leader Says U.S. Airdrop Aided ISIS Militants'],
#  ['Christian Bale Drops Out of Steve Jobs Biopic'],
#  ["Here Are Microsoft's New Robot Security Guards"],
#  ['Apple Watch battery will require nightly charging'],
#  ['Nigeria says it has deal with Boko Haram to release kidnapped girls'],
#  ['Satirical news site attacks China’s weird English names'],
#  ['U.S.', 'Hostage Luke Somers Killed During Yemen Rescue Bid: Family'],
#  ['ISIS launch SCORPION BOMBS to spread panic in Iraq'],
#  ['More than 200 kidnapped Nigerian girls to be released after deal reached with Boko Haram'],
#  ['Kim Jong-Un planning Scottish restaurant'],
#  ['Dog abandoned at Ayr station with belongings in suitcase'],
#  ['"This is the recording you thought you\'d lost forever"'],
#  ['That’s one way to clean it: Apple Watch will reportedly survive a trip through the shower'],
#  ['This Soap Opera Star Reportedly Had His Testicles Stolen By An ‘Attractive Blonde’ Organ Trafficker'],
#  ['Stainless steel Apple Watch could cost just $499, but gold will be 10 times as pricey'],
#  ['Lebanon confirms holding ISIS chief’s kin'],
#  ['Pentagon: Airstrike killed terror leader in Somalia'],
#  ['Audio recording allegedly captures at least 10 shots fired in Michael Brown killing'],
#  ["Luke Somers 'killed in failed rescue attempt in Yemen'"],
#  ['Does ISIS Have Ebola?', 'Probably Not!', 'Media Reports It Anyway'],
#  ["ISIS Executioner 'Jihadi John' Is Named as Mohammed Emwazi"],
#  ['Michael Phelps’ alleged girlfriend says she was born intersex'],
#  ["US officials: Video shows American's execution"],
#  ["ISIS fighters 'have contracted Ebola': World Health Organisation investigating reports militants showed up at Iraqi hospital with lethal disease"],
#  ['Amazon to launch first brick-and-mortar store, report says'],
#  ["REPORT: Apple's Watch Will Come In 2 Storage Sizes"],
#  ["Batmobile wasn't stolen: Cops"],
#  ['Pumpkin Spice Condoms, And 6 Other Flavors That Aren’t Happening'],
#  ['The Story Of The High School Trader Who Made $72 Million Is A Rumor Spun Out Of Control'],
#  ['Tourist wakes to find strange red trail on his stomach - and discovers a spider has burrowed through his appendix scar and crawled UNDER his skin while on holiday in Bali'],
#  ["Questions raised over Nicaragua 'meteorite'"],
#  ['A Mass Grave Points to a Student Massacre in Mexico'],
#  ["IS militant 'Jihadi John' named as Mohammed Emwazi from London"],
#  ['ISIS leader ‘killed’ in US airstrikes'],
#  ['Iraqi media says ISIS militants have contracted Ebola'],
#  ['Lynch Mob Castrates Alleged Rapist In Rajasthan'],
#  ['Nigeria says ceasefire agreed with Boko Haram'],
#  ['UPDATE: BATMAN v SUPERMAN Batmobile Reportedly Stolen By (Shocker!)',
#   'Detroit Locals'],
#  ['ISIS Militants Have Contracted Ebola: Iraqi, Kurdish Media Reports'],
#  ["Israeli Canadian fighting ISIS posts on Facebook: I'm safe and secure"],
#  ['Islamic Tribunal Using Sharia Law In Texas Has Been Confirmed Tribunal members say they will avoid Sharia\'s "criminal law."'],
#  ['Video showing American journalist beheaded believed real, officials and family say'],
#  ["Officials shoot down congressman's claims ISIS terrorists are running across US-Mexico border"],
#  ...]
